# %% [markdown]
# ### 载入环境

# %%
from damndata.damn_geoSpider import geoautonavi as amaPoi
import pandas as pd

# %% [markdown]
# ### 参数设置

# %% [markdown]
# ###### 说明**
# 详细文档：         https://lbs.amap.com/api/webservice/guide/api/search
#
# http接口：         'resapi.amap.com/v3/place/'
#
# 检索模式：（地理参数 'geo'）
#
# 关键字搜索：        'text?'     >>>  'city=' (citycode|adcode)
#
# 周边搜索：         'around?'    >>>  'location='、'radius='
#
# 多边形搜索：        'polygon?'   >>>  'polygon='
#
# 参数：             key、'geo'、types|keywords

# %%
http      = 'restapi.amap.com/v3/place/around?'
key       = 'key=f9257dab1e8214b074587fe16484cb1e'
para_loc  = '&location=120.233851,30.167682&radius=800'
para_type = '&types=050000|070000|090000|120300|141200|160000|170100|170200'

# %% [markdown]
# ### 爬取

# %%
URL=http+key+para_loc+para_type+'&output=json&offset=25&extensions=all&page='
pois=amaPoi.getpois(URL)                                                           #请求数据

filePath = 'E:/zixunHUANG/2019-2021_Project/202007_FridaySalon/week200724/test.csv'#设定文件路径
amaPoi.write_to_csv(pois,filePath)                                                 #写入本地
print('Done!!!')
# Out:
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Done!!!

# %% [markdown]
# ### 读入爬取结果

# %%
df=pd.read_csv(filePath,index_col='Unnamed: 0')
df
# Out:
#             id                        name      wgslng     wgslat adname  \
# 0   B0GUYZ2ME5                 简鹿糖水铺金湖艺境城店  120.228993  30.170145    萧山区
# 1   B0GRAZ3QZY                         肯德基  120.228988  30.170157    萧山区
# 2   B0FFJNT73W                     都会艺境售楼处  120.229098  30.170268    萧山区
# 3   B0GUM7859O                朝天门火锅(杭州湘湖店)  120.229051  30.170334    萧山区
# 4   B0GR1ZXHKS                  都会艺境商业街招商部  120.228925  30.170261    萧山区
# 5   B0GDD7UITV                 一点点(金湖艺境城店)  120.228902  30.170082    萧山区
# 6   B0FFKXUMCW                       古茗湘湖店  120.228872  30.170117    萧山区
# 7   B0FFLI4TAW     菜鸟驿站(杭州广宁小区蜀山路427号店菜鸟驿)  120.229666  30.170505    萧山区
# 8   B0FFHI50J1              萧山(地铁湘湖站)旅游咨询点  120.229562  30.170655    萧山区
# 9   B0GDVS7DLM                    宝哥面(湘湖店)  120.228871  30.170482    萧山区
# 10  B0FFJCYS9V                沙县小吃(湘湖地铁站店)  120.229139  30.169501    萧山区
# 11  B0FFIPRET6                    中国兰州牛肉拉面  120.229132  30.169558    萧山区
# 12  B0FFIGS3FT              五芳斋回味餐厅(风情大道店)  120.229156  30.169535    萧山区
# 13  B0GU47VZ5R                 吉祥馄饨(都会艺境店)  120.228688  30.170414    萧山区
# 14  B0FFM5KJR3                 银和设计谷设计师俱乐部  120.228681  30.169832    萧山区
# 15  B0FFLLCX5C                  怪兽充电(天猫小店)  120.229043  30.169480    萧山区
# 16  B0FFLAULB2                    街电(天猫小店)  120.229043  30.169480    萧山区
# 89  B0FFL962YX       菜鸟驿站(杭州市萧山区湘湖家园883号店)  120.231568  30.176576    萧山区
# 90  B0FFLJVWZ4    杭州办事综合自助终端机（萧山区城厢街道湘湖社区）  120.232616  30.176227    萧山区
# 91  B0FFK8FON9                 一景乳业萧山第一分公司  120.231980  30.176552    萧山区
# 92  B0FFF2MEI6                  湘湖社区文化活动中心  120.232582  30.176304    萧山区
# 93  B0FFLIQ27E                   好嘞易腐垃圾收集站  120.233522  30.176000    萧山区
# 94  B023B0BPQY                   湘湖社区卫生服务站  120.232555  30.176518    萧山区
# 95  B0FFMGPHDY             萧山区城厢街道社区卫生服务中心  120.232457  30.176534    萧山区
# 96  B023B0BPQS               湘湖农家土菜馆(萧西路店)  120.231587  30.177015    萧山区
# 97  B0GRD9KLVV                        阿芳理发  120.231691  30.177015    萧山区
# 98  B0FFJRSKZD                        阿芳理发  120.231812  30.176999    萧山区
# 99  B0FFIVGYV4              高盛龙涤物业管理集团有限公司  120.233160  30.176524    萧山区
#
#         cost rating                          type
# 0      16.00    3.5                  餐饮服务;甜品店;甜品店
# 1         []     []                  餐饮服务;快餐厅;快餐厅
# 2         []     []            生活服务;生活服务场所;生活服务场所
# 3     119.00    5.0                  餐饮服务;中餐厅;火锅店
# 4         []     []            生活服务;生活服务场所;生活服务场所
# 5      11.00    4.9              餐饮服务;餐饮相关场所;餐饮相关
# 6      12.00    4.9                  餐饮服务;冷饮店;冷饮店
# 7         []     []                生活服务;物流速递;物流速递
# 8         []     []            生活服务;生活服务场所;生活服务场所
# 9      21.00    3.5                  餐饮服务;中餐厅;中餐厅
# 10     12.00    3.5                  餐饮服务;快餐厅;快餐厅
# 11        []     []                 餐饮服务;中餐厅;清真菜馆
# 12     27.00    3.5                  餐饮服务;中餐厅;中餐厅
# 13        []     []                  餐饮服务;快餐厅;快餐厅
# 14        []     []                    公司企业;公司;公司
# 15        []     []                 生活服务;共享设备;充电宝
# 16        []     []                 生活服务;共享设备;充电宝
# 17     16.00    4.2              餐饮服务;餐饮相关场所;餐饮相关
# 18        []     []            生活服务;生活服务场所;生活服务场所
# 19        []     []                 生活服务;共享设备;充电宝
# 20     27.00    3.5              餐饮服务;餐饮相关场所;餐饮相关
# 21      8.00     []                  餐饮服务;冷饮店;冷饮店
# 22        []    3.0            生活服务;生活服务场所;生活服务场所
# 23        []     []                 生活服务;共享设备;充电宝
# 24        []    3.5                  餐饮服务;中餐厅;火锅店
# 25        []     []            生活服务;生活服务场所;生活服务场所
# 26        []    3.5              餐饮服务;餐饮相关场所;餐饮相关
# 27        []     []                  餐饮服务;中餐厅;中餐厅
# 28        []     []                    公司企业;公司;公司
# 29     86.00    5.0              生活服务;美容美发店;美容美发店
# ..       ...    ...                           ...
# 70        []     []                 科教文化服务;学校;幼儿园
# 71     85.00    5.0              生活服务;美容美发店;美容美发店
# 72        []     []             医疗保健服务;医药保健销售店;药房
# 73        []     []                    公司企业;公司;公司
# 74        []     []              餐饮服务;餐饮相关场所;餐饮相关
# 75  34604.00     []                 商务住宅;住宅区;住宅小区
# 76        []     []                  商务住宅;住宅区;住宅区
# 77        []     []                 科教文化服务;学校;幼儿园
# 78        []     []                 商务住宅;住宅区;住宅小区
# 79     67.00    3.5                 餐饮服务;中餐厅;综合酒楼
# 80        []     []                  商务住宅;住宅区;住宅区
# 81        []     []            生活服务;生活服务场所;生活服务场所
# 82  27754.00     []                 商务住宅;住宅区;住宅小区
# 83        []     []                    公司企业;公司;公司
# 84        []     []                生活服务;物流速递;物流速递
# 85        []     []                生活服务;维修站点;维修站点
# 86        []     []                  医疗保健服务;诊所;诊所
# 87        []     []                生活服务;物流速递;物流速递
# 88        []     []                 科教文化服务;学校;幼儿园
# 89        []     []                生活服务;物流速递;物流速递
# 90        []     []            生活服务;生活服务场所;生活服务场所
# 91        []     []                    公司企业;公司;公司
# 92        []     []  商务住宅;住宅区;社区中心|科教文化服务;文化宫;文化宫
# 93        []     []            生活服务;生活服务场所;生活服务场所
# 94        []     []               医疗保健服务;综合医院;卫生院
# 95        []     []               医疗保健服务;综合医院;卫生院
# 96     71.00    3.0                  餐饮服务;中餐厅;中餐厅
# 97        []     []              生活服务;美容美发店;美容美发店
# 98        []     []              生活服务;美容美发店;美容美发店
# 99        []     []                    公司企业;公司;公司
#
# [100 rows x 8 columns]

# %% [markdown]
# ### 定制自己的POI请求程序

# %%
type_list=['050000','060000','070000']

# %%
for i,typei in enumerate(type_list):
    print(i,typei)
    URL_i=http+key+para_loc+typei+'&output=json&offset=25&extensions=all&page='
    pois_i=amaPoi.getpois(URL_i)                                                           

    filePath_i = 'E:/zixunHUANG/2019-2021_Project/202007_FridaySalon/week200724/'+str(i).zfill(2)+'.csv'
    amaPoi.write_to_csv(pois_i,filePath_i)                                                 
    print('Done!!!')
# Out:
# 0 050000
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
#
# Scraping...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-376b7908c9e5> in <module>()
#       2     print(i,typei)
#       3     URL_i=http+key+para_loc+typei+'&output=json&offset=25&extensions=all&page='
# ----> 4     pois_i=amaPoi.getpois(URL_i)
#       5
#       6     filePath_i = 'E:/zixunHUANG/2019-2021_Project/202007_FridaySalon/week200724/'+str(i).zfill(2)+'.csv'
#
# E:\zixunHUANG\2019-2021_Project\202007_FridaySalon\week200724\amaPoi.py in getpois(poi_search_url)
#      30     poilist = []
#      31     while True:
# ---> 32         result = getpoi_page(poi_search_url, i)
#      33         print('Scraping...\n')
#      34         result = json.loads(result)
#
# E:\zixunHUANG\2019-2021_Project\202007_FridaySalon\week200724\amaPoi.py in getpoi_page(poi_search_url, page)
#      18     req_url = 'http://'+poi_search_url+str(page)
#      19     data = ''
# ---> 20     with request.urlopen(req_url) as f:
#      21         data = f.read()
#      22         data = data.decode('utf-8')
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_open(self, req)
#    1344
#    1345     def http_open(self, req):
# -> 1346         return self.do_open(http.client.HTTPConnection, req)
#    1347
#    1348     http_request = AbstractHTTPHandler.do_request_
#
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
# -> 1321             r = h.getresponse()
#    1322         except:
#    1323             h.close()
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:
